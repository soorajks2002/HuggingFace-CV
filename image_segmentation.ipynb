# %%
! pip install transformers timm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.2 MB/s eta 0:00:00

# %%
from transformers import pipeline

segmenter = pipeline("image-segmentation", model="facebook/detr-resnet-50-panoptic")
# Out:
# ...
# Some weights of the model checkpoint at facebook/detr-resnet-50-panoptic were not used when initializing DetrForSegmentation: ['detr.model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'detr.model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'detr.model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked', 'detr.model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForSegmentation from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForSegmentation from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
image = Image.open("/content/download (5).jpg")

# %%
outputs = segmenter(image)

# %%
outputs
# Out:
# [{'score': 0.947595,
#   'label': 'person',
#   'mask': <PIL.Image.Image image mode=L size=262x193>},
#  {'score': 0.999132,
#   'label': 'person',
#   'mask': <PIL.Image.Image image mode=L size=262x193>},
#  {'score': 0.998309,
#   'label': 'tie',
#   'mask': <PIL.Image.Image image mode=L size=262x193>},
#  {'score': 0.997927,
#   'label': 'person',
#   'mask': <PIL.Image.Image image mode=L size=262x193>}]

# %%
plt.imshow(image)

# %%
print(outputs[0]['label'])
plt.imshow(outputs[0]['mask'])
# Out:
# person

# %%
print(outputs[1]['label'])
plt.imshow(outputs[1]['mask'])
# Out:
# person

# %%
print(outputs[2]['label'])
plt.imshow(outputs[2]['mask'])
# Out:
# tie

# %%
print(outputs[3]['label'])
plt.imshow(outputs[3]['mask'])
# Out:
# person
